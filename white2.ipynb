# %% [markdown]
# Date :- 3/07/2026

# %% [markdown]
# Lecture : 1st Feb Live Class dict , conditional ,loop

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 ={"key": "shreyansh"}

# %%
d1
# Out:
# {'key': 'shreyansh'}

# %%
d2 ={'name': 'shreyansh', 'email': 'shreyanshhbtu@gmail.com' ,'Phone no.':'7607621401'}

# %%
d2
# Out:
# {'name': 'shreyansh',
#  'email': 'shreyanshhbtu@gmail.com',
#  'Phone no.': '7607621401'}

# %%
d3 = {234 : 'gupta', "_war" :'shreyansh',True :12244}

# %%
d3
# Out:
# {234: 'gupta', '_war': 'shreyansh', True: 12244}

# %%
d3['234']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 d3['234']
#
# KeyError: '234'

# %%
 d3
# Out:
# {234: 'gupta', '_war': 'shreyansh', True: 12244}

# %%
d3[234]
# Out:
# 'gupta'

# %%
d3[True]
# Out:
# 12244

# %%
d3[1]
# Out:
# 12244

# %%
d4 ={'Name ':'shreyansh','Email_id':'shreyanshhbtu@gmail.com', 'Name' :'SHREYANSH'}

# %%
d4['Name']
# Out:
# 'SHREYANSH'

# %%
d5 = {"company":"pwskills","course": ["web development","data science","java with dsa and system design"]}

# %%
d5
# Out:
# {'company': 'pwskills',
#  'course': ['web development',
#   'data science',
#   'java with dsa and system design']}

# %%
d5['course']
# Out:
# ['web development', 'data science', 'java with dsa and system design']

# %%
d5['course'][2]
# Out:
# 'java with dsa and system design'

# %%
d6 ={"number":[2,34,3,34,34],"assignment":(1,2,3,4,5,6),"launch_date":{28,12,14},"class_time":{"Web_dev":8 ,"Data Science Master":9,"Java_with_DSA_and_System_design":10}}

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'Web_dev': 8,
#   'Data Science Master': 9,
#   'Java_with_DSA_and_System_design': 10}}

# %%
d6['class_time']['Java_with_DSA_and_System_design']
# Out:
# 10

# %%
d6['mentor'] =["sudhansu","krish","anurag","hayder"]

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'Web_dev': 8,
#   'Data Science Master': 9,
#   'Java_with_DSA_and_System_design': 10},
#  'mentor': ['sudhansu', 'krish', 'anurag', 'hayder']}

# %%
del d6['number']

# %%
d6
# Out:
# {'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'Web_dev': 8,
#   'Data Science Master': 9,
#   'Java_with_DSA_and_System_design': 10},
#  'mentor': ['sudhansu', 'krish', 'anurag', 'hayder']}

# %%
list(d6.keys())
# Out:
# ['assignment', 'launch_date', 'class_time', 'mentor']

# %%
list(list(d6.values()))
# Out:
# [(1, 2, 3, 4, 5, 6),
#  {12, 14, 28},
#  {'Web_dev': 8,
#   'Data Science Master': 9,
#   'Java_with_DSA_and_System_design': 10},
#  ['sudhansu', 'krish', 'anurag', 'hayder']]

# %%
g6.item()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 g6.item()
#
# NameError: name 'g6' is not defined

# %%
list(d6.items())
# Out:
# [('assignment', (1, 2, 3, 4, 5, 6)),
#  ('launch_date', {12, 14, 28}),
#  ('class_time',
#   {'Web_dev': 8,
#    'Data Science Master': 9,
#    'Java_with_DSA_and_System_design': 10}),
#  ('mentor', ['sudhansu', 'krish', 'anurag', 'hayder'])]

# %%
d6.pop('assignment')
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
d6.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 d6.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
marks =65
if marks >= 80 :
    print("you will be a part of A0 batch")
elif marks >= 60 and marks < 80:
    print("you will be a part of A1 batch")
elif marks >=40 and  marks <60:
    print("you will be a part of A2 batch")
else:
    print("you will be a part of A3 batch")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 marks = input(" enter your marks")
# ----> 2 if marks >= 80 :
#       3     print("you will be a part of A0 batch")
#       4 elif marks >= 60 and marks < 80:
#       5     print("you will be a part of A1 batch")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
10<= 80
# Out:
# True

# %%
marks = input("enter your marks" )

# %%
2+3
# Out:
# 5

# %%
5+8
# Out:
# 13

# %%
marks = float(input("enter your marks" ))
if marks >= 80 :
    print("you will be a part of A0 batch")
elif marks >= 60 and marks < 80:
    print("you will be a part of A1 batch")
elif marks >=40 and  marks <60:
    print("you will be a part of A2 batch")
else:
    print("you will be a part of A3 batch")
# Out:
# you will be a part of A0 batch

# %%
price = int(input("Enter the price"))
if price > 1000:
    print('I will not purchase')
else:
    print('I will purchase')
# Out:
# I will purchase

# %%
price = int(input("Enter the price"))
if price > 1000:
    print('I will not purchase')

# %%
l =[1,2,3,4,5,6,7,8,9]

# %%
l +1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l +1
#
# TypeError: can only concatenate list (not "int") to list

# %%
l[0] +1
# Out:
# 2

# %%
l1 =[]

# %%
l1.append(l[0] +1)

# %%
l1
# Out:
# [2]

# %%
l1.append(l[1] +1,l[2] +1,l[3] +1,l[4] +1,l[5] +1,l[6] +1,l[7] +1,l[0] +1,l[8] +1,l[9] +1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l1.append(l[1] +1,l[2] +1,l[3] +1,l[4] +1,l[5] +1,l[6] +1,l[7] +1,l[0] +1,l[8] +1,l[9] +1)
#
# IndexError: list index out of range

# %%
l =[1,2,3,4,5,6,7,8,9]

# %%
l1 = []
for i in l:
    print(i+1)
    l1.append(i+1)
l1
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
l3 = ["shreyansh", "gupta","pwskills" , "course"]

# %%
l4 = []
for i in l3:
    print(i)
    l4.append(i.upper())
l4
# Out:
# shreyansh
# gupta
# pwskills
# course
# ['SHREYANSH', 'GUPTA', 'PWSKILLS', 'COURSE']

# %%
l5 = [1,2,3,4,4,"shreyansh", "kumar", 324,34.456, "abc"]

# %%
int_list = [x for x in l5 if isinstance(x, int)]
str_list = [x for x in l5 if isinstance(x, str)]

int_list, str_list
# Out:
# ([1, 2, 3, 4, 4, 324], ['shreyansh', 'kumar', 'abc'])
